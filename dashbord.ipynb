# %% [markdown]
# **Important Libraries**

# %%
# %pip install panel
# %pip install hvplot
# Out:
# Requirement already satisfied: panel in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (0.12.7)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (0.4.8)
# Requirement already satisfied: param>=1.10.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (1.12.1)
# Requirement already satisfied: bleach in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (5.0.0)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (2.26.0)
# Requirement already satisfied: setuptools<61,>=42 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (57.4.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (2.2.0)
# Requirement already satisfied: bokeh<2.5.0,>=2.4.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (2.4.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (4.64.0)
# Requirement already satisfied: markdown in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel) (3.3.4)
# Requirement already satisfied: tornado>=5.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (5.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (1.19.5)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (8.3.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (20.9)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (4.1.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from packaging>=16.8->bokeh<2.5.0,>=2.4.0->panel) (2.4.7)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bleach->panel) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel) (2.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel) (3.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Admin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: hvplot in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (0.7.3)
# Requirement already satisfied: colorcet>=2 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from hvplot) (3.0.0)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from hvplot) (2.4.2)
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from hvplot) (1.3.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from hvplot) (1.14.8)
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from hvplot) (1.19.5)
# Requirement already satisfied: tornado>=5.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (5.4.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (20.9)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (4.1.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (8.3.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.0.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: param>=1.7.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from colorcet>=2->hvplot) (1.12.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.2.0)
# Requirement already satisfied: panel>=0.8.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from holoviews>=1.11.0->hvplot) (0.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas->hvplot) (2021.1)
# Requirement already satisfied: setuptools<61,>=42 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (57.4.0)
# Requirement already satisfied: bleach in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (5.0.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.64.0)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.26.0)
# Requirement already satisfied: markdown in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.4)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.15.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.48.0->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from bleach->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Admin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
print("Setup Complete")
# Out:
# Setup Complete

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():
    df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
    pn.state.cache['data'] = df.copy()

else:
    df = pn.state.cache['data']
df
# Out:
#       iso_code      country  year     co2  co2_per_capita  trade_co2  \
# 0          AFG  Afghanistan  1949   0.015           0.002        NaN
# 1          AFG  Afghanistan  1950   0.084           0.011        NaN
# 2          AFG  Afghanistan  1951   0.092           0.012        NaN
# 3          AFG  Afghanistan  1952   0.092           0.012        NaN
# 4          AFG  Afghanistan  1953   0.106           0.013        NaN
# ...        ...          ...   ...     ...             ...        ...
# 25186      ZWE     Zimbabwe  2016  10.738           0.765      1.415
# 25187      ZWE     Zimbabwe  2017   9.582           0.673      1.666
# 25188      ZWE     Zimbabwe  2018  11.854           0.821      1.308
# 25189      ZWE     Zimbabwe  2019  10.949           0.748      1.473
# 25190      ZWE     Zimbabwe  2020  10.531           0.709        NaN
#
#        cement_co2  cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0             NaN                    NaN     0.015                0.002  ...
# 1             NaN                    NaN     0.021                0.003  ...
# 2             NaN                    NaN     0.026                0.003  ...
# 3             NaN                    NaN     0.032                0.004  ...
# 4             NaN                    NaN     0.038                0.005  ...
# ...           ...                    ...       ...                  ...  ...
# 25186       0.639                  0.046     6.959                0.496  ...
# 25187       0.678                  0.048     5.665                0.398  ...
# 25188       0.697                  0.048     7.101                0.492  ...
# 25189       0.697                  0.048     6.020                0.411  ...
# 25190       0.697                  0.047     6.257                0.421  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 0                                NaN      NaN                 NaN
# 1                                NaN      NaN                 NaN
# 2                                NaN      NaN                 NaN
# 3                                NaN      NaN                 NaN
# 4                                NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 25186                          2.076    11.50               0.820
# 25187                          2.023    11.62               0.816
# 25188                          2.173    11.96               0.828
# 25189                            NaN      NaN                 NaN
# 25190                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 0                NaN                       NaN   7624058.0           NaN
# 1                NaN                       NaN   7752117.0  9.421400e+09
# 2                NaN                       NaN   7840151.0  9.692280e+09
# 3                NaN                       NaN   7935996.0  1.001732e+10
# 4                NaN                       NaN   8039684.0  1.063052e+10
# ...              ...                       ...         ...           ...
# 25186           6.21                     0.443  14030338.0  2.096179e+10
# 25187           6.35                     0.446  14236599.0  2.194784e+10
# 25188           6.59                     0.456  14438812.0  2.271535e+10
# 25189            NaN                       NaN  14645473.0           NaN
# 25190            NaN                       NaN  14862927.0           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                             NaN                NaN             NaN
# 1                             NaN                NaN             NaN
# 2                             NaN                NaN             NaN
# 3                             NaN                NaN             NaN
# 4                             NaN                NaN             NaN
# ...                           ...                ...             ...
# 25186                        47.5           3385.574           1.889
# 25187                         NaN                NaN             NaN
# 25188                         NaN                NaN             NaN
# 25189                         NaN                NaN             NaN
# 25190                         NaN                NaN             NaN
#
# [25191 rows x 60 columns]

# %%
# return the column labels
df.columns
# Out:
# Index(['iso_code', 'country', 'year', 'co2', 'co2_per_capita', 'trade_co2',
#        'cement_co2', 'cement_co2_per_capita', 'coal_co2',
#        'coal_co2_per_capita', 'flaring_co2', 'flaring_co2_per_capita',
#        'gas_co2', 'gas_co2_per_capita', 'oil_co2', 'oil_co2_per_capita',
#        'other_industry_co2', 'other_co2_per_capita', 'co2_growth_prct',
#        'co2_growth_abs', 'co2_per_gdp', 'co2_per_unit_energy',
#        'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_co2', 'cumulative_cement_co2',
#        'cumulative_coal_co2', 'cumulative_flaring_co2', 'cumulative_gas_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'trade_co2_share',
#        'share_global_co2', 'share_global_cement_co2', 'share_global_coal_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_oil_co2', 'share_global_other_co2',
#        'share_global_cumulative_co2', 'share_global_cumulative_cement_co2',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_oil_co2',
#        'share_global_cumulative_other_co2', 'total_ghg', 'ghg_per_capita',
#        'total_ghg_excluding_lucf', 'ghg_excluding_lucf_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'population', 'gdp', 'primary_energy_consumption', 'energy_per_capita',
#        'energy_per_gdp'],
#       dtype='object')

# %%
# exemple of data for a specific country
df[df['country'] == 'Tunisia']
# Out:
#       iso_code  country  year     co2  co2_per_capita  trade_co2  cement_co2  \
# 22725      TUN  Tunisia  1916   0.011           0.005        NaN         NaN
# 22726      TUN  Tunisia  1917   0.029           0.013        NaN         NaN
# 22727      TUN  Tunisia  1918   0.040           0.018        NaN         NaN
# 22728      TUN  Tunisia  1919     NaN             NaN        NaN         NaN
# 22729      TUN  Tunisia  1920   0.029           0.012        NaN         NaN
# ...        ...      ...   ...     ...             ...        ...         ...
# 22825      TUN  Tunisia  2016  29.008           2.566     -1.512       3.594
# 22826      TUN  Tunisia  2017  29.231           2.557     -1.487       3.206
# 22827      TUN  Tunisia  2018  29.363           2.539     -1.990       3.125
# 22828      TUN  Tunisia  2019  30.011           2.566     -1.735       3.125
# 22829      TUN  Tunisia  2020  28.127           2.380        NaN       3.125
#
#        cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 22725                    NaN     0.011                0.005  ...
# 22726                    NaN     0.029                0.013  ...
# 22727                    NaN     0.040                0.018  ...
# 22728                    NaN       NaN                  NaN  ...
# 22729                    NaN     0.029                0.012  ...
# ...                      ...       ...                  ...  ...
# 22825                  0.318       NaN                  NaN  ...
# 22826                  0.280       NaN                  NaN  ...
# 22827                  0.270       NaN                  NaN  ...
# 22828                  0.267       NaN                  NaN  ...
# 22829                  0.264       NaN                  NaN  ...
#
#        ghg_excluding_lucf_per_capita  methane  methane_per_capita  \
# 22725                            NaN      NaN                 NaN
# 22726                            NaN      NaN                 NaN
# 22727                            NaN      NaN                 NaN
# 22728                            NaN      NaN                 NaN
# 22729                            NaN      NaN                 NaN
# ...                              ...      ...                 ...
# 22825                          3.515     6.29               0.556
# 22826                          3.561     6.35               0.555
# 22827                          3.554     6.42               0.555
# 22828                            NaN      NaN                 NaN
# 22829                            NaN      NaN                 NaN
#
#        nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 22725            NaN                       NaN   2281092.0           NaN
# 22726            NaN                       NaN   2293553.0           NaN
# 22727            NaN                       NaN   2305150.0           NaN
# 22728            NaN                       NaN   2319610.0           NaN
# 22729            NaN                       NaN   2336979.0           NaN
# ...              ...                       ...         ...           ...
# 22825           3.34                     0.295  11303942.0  1.245515e+11
# 22826           3.26                     0.285  11433438.0  1.269404e+11
# 22827           3.32                     0.287  11565203.0  1.303221e+11
# 22828            NaN                       NaN  11694721.0           NaN
# 22829            NaN                       NaN  11818618.0           NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp
# 22725                         NaN                NaN             NaN
# 22726                         NaN                NaN             NaN
# 22727                         NaN                NaN             NaN
# 22728                         NaN                NaN             NaN
# 22729                         NaN                NaN             NaN
# ...                           ...                ...             ...
# 22825                     115.572          10223.993           0.979
# 22826                         NaN                NaN             NaN
# 22827                         NaN                NaN             NaN
# 22828                         NaN                NaN             NaN
# 22829                         NaN                NaN             NaN
#
# [105 rows x 60 columns]

# %% [markdown]
# **Minor data preprocessing**

# %%
# Fill NANs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# **CO2 emission over time by continent**

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
# integration of the widgets , data pipeline
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_pipeline

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent")

# %% [markdown]
# **Table - CO2 emission over time by continent**

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
# Out:
# WARNING:param.Tabulator1635535: Setting non-parameter attribute title=table of CO2 emission by continent using a mechanism intended only for parameters

# %% [markdown]
# **CO2 vs GDP scatterplot**

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)

# %% [markdown]
# **Bar chart with CO2 sources by continent**

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')

# %% [markdown]
# **Creating Dashboard**

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('world.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# WARNING:param.Tabulator1642490: Setting non-parameter attribute title=table of CO2 emission by continent using a mechanism intended only for parameters
# Launching server at http://localhost:55120
# WARNING:param.Tabulator1682170: Setting non-parameter attribute title=table of CO2 emission by continent using a mechanism intended only for parameters
# WARNING:param.Tabulator1686901: Setting non-parameter attribute title=table of CO2 emission by continent using a mechanism intended only for parameters
